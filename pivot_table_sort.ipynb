# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Let's build dataframe (it is just an example)

# %%
df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                         "bar", "bar", "bar", "bar"],
                   "B": ["one", "one", "one", "two", "two",
                         "one", "one", "two", "two"],
                   "C": ["small", "large", "large", "small",
                         "small", "large", "small", "small",
                         "large"],
                   "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                   "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})

# %%
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %% [markdown]
# Let's build pivot table

# %%
pivot_table = pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'], aggfunc=[min, np.mean, max])

# %%
pivot_table
# Out:
#           min         mean           max
#             D  E         D         E   D  E
# A   C
# bar large   4  6  5.500000  7.500000   7  9
#     small   5  8  5.500000  8.500000   6  9
# foo large   2  4  2.000000  4.500000   2  5
#     small   1  2  2.333333  4.333333   3  6

# %% [markdown]
# We should sort by mean values for column D. So, we should invoke sort_values function and put column name as a parameter. Let's see what columns does our dataframehave

# %%
pivot_table.columns
# Out:
# MultiIndex([( 'min', 'D'),
#             ( 'min', 'E'),
#             ('mean', 'D'),
#             ('mean', 'E'),
#             ( 'max', 'D'),
#             ( 'max', 'E')],
#            )

# %% [markdown]
# We have multiIndex columns. We can invoke function sort_values and provide tuple ('mean', 'D') as a parameter:

# %%
pivot_table.sort_values(('mean', 'D'))
# Out:
#           min         mean           max
#             D  E         D         E   D  E
# A   C
# foo large   2  4  2.000000  4.500000   2  5
#     small   1  2  2.333333  4.333333   3  6
# bar large   4  6  5.500000  7.500000   7  9
#     small   5  8  5.500000  8.500000   6  9

# %% [markdown]
# We can do it in one line:

# %%
pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'], aggfunc=[min, np.mean, max]).sort_values(('mean', 'D'))
# Out:
#           min         mean           max
#             D  E         D         E   D  E
# A   C
# foo large   2  4  2.000000  4.500000   2  5
#     small   1  2  2.333333  4.333333   3  6
# bar large   4  6  5.500000  7.500000   7  9
#     small   5  8  5.500000  8.500000   6  9
